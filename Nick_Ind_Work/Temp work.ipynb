# %%
# Data Science
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, text, inspect, func

# %%
# Read in CSV
Santa_Barbara = pd.read_csv("../Resources/Santa_Barbara.csv")
Santa_Barbara.head()
# Out:
#               business_id                     name                address  \
# 0  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 1  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 2  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 3  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 4  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
#
#             city state  postal_code  latitude   longitude  stars  \
# 0  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 1  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 2  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 3  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 4  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
#
#    review_count                       categories                 user_id  \
# 0           110  Restaurants, Breakfast & Brunch  8H-17uPX904DiVyNFIixPg
# 1           110  Restaurants, Breakfast & Brunch  ukgieEhXwin4YRqsdguLrA
# 2           110  Restaurants, Breakfast & Brunch  H6frBOvhhQbs7HWKcH1lNA
# 3           110  Restaurants, Breakfast & Brunch  tQCc9h1zjbMbrPYGfrMKJg
# 4           110  Restaurants, Breakfast & Brunch  94cMFXuUjTdaKWnxRJjTkg
#
#    review_stars                                               text  \
# 0             5  Been going here for years!  Always great food,...
# 1             2  We found the food and coffee disappointing but...
# 2             5  Just moved into the neighborhood and decided t...
# 3             5  I loved this place. My boyfriend and I came fo...
# 4             5  Santa Barbara's very best breakfast burrito! T...
#
#                   date
# 0  2019-02-10 22:53:31
# 1  2013-12-27 22:49:20
# 2  2018-10-07 15:19:13
# 3  2017-10-30 02:38:31
# 4  2015-09-17 17:17:03

# %%
# Change Date to ####-##-##
Santa_Barbara['date'] = pd.to_datetime(Santa_Barbara['date'])
Santa_Barbara['date'] = pd.to_datetime(Santa_Barbara['date'], unit='s').dt.strftime('%Y-%m-%d')

# %%
Santa_Barbara.head()
# Out:
#               business_id                     name                address  \
# 0  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 1  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 2  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 3  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 4  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
#
#             city state  postal_code  latitude   longitude  stars  \
# 0  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 1  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 2  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 3  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 4  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
#
#    review_count                       categories                 user_id  \
# 0           110  Restaurants, Breakfast & Brunch  8H-17uPX904DiVyNFIixPg
# 1           110  Restaurants, Breakfast & Brunch  ukgieEhXwin4YRqsdguLrA
# 2           110  Restaurants, Breakfast & Brunch  H6frBOvhhQbs7HWKcH1lNA
# 3           110  Restaurants, Breakfast & Brunch  tQCc9h1zjbMbrPYGfrMKJg
# 4           110  Restaurants, Breakfast & Brunch  94cMFXuUjTdaKWnxRJjTkg
#
#    review_stars                                               text        date
# 0             5  Been going here for years!  Always great food,...  2019-02-10
# 1             2  We found the food and coffee disappointing but...  2013-12-27
# 2             5  Just moved into the neighborhood and decided t...  2018-10-07
# 3             5  I loved this place. My boyfriend and I came fo...  2017-10-30
# 4             5  Santa Barbara's very best breakfast burrito! T...  2015-09-17

# %%
# Look for city spelling errors
Santa_Barbara.city.unique()
# Out:
# array(['Santa Barbara', 'Santa  Barbara'], dtype=object)

# %%
# Replace city spelling errors
Santa_Barbara['city'] = Santa_Barbara['city'].str.replace('Santa  Barbara', 'Santa Barbara')
Santa_Barbara.city.unique()
# Out:
# array(['Santa Barbara'], dtype=object)

# %%
# Find min/max of date range
print(Santa_Barbara['date'].min())
print(Santa_Barbara['date'].max())
# Out:
# 2005-03-01
# 2022-01-19

# %%
# Return only 10 years of data
Santa_Barbara = Santa_Barbara[Santa_Barbara['date'] >= '2012-01-01']
print(Santa_Barbara['date'].min())
print(Santa_Barbara['date'].max())
# Out:
# 2012-01-01
# 2022-01-19

# %%
# Drop text columns - makes db too large
Santa_Barbara_Clean = Santa_Barbara.drop('text', axis=1)
Santa_Barbara_Clean.head()
# Out:
#               business_id                     name                address  \
# 0  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 1  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 2  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 3  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
# 4  6VVbLYay8czrjKJ4xRoTxQ  Judge For Yourself Cafe  1218 Santa Barbara St
#
#             city state  postal_code  latitude   longitude  stars  \
# 0  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 1  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 2  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 3  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
# 4  Santa Barbara    CA        93101  34.42599 -119.702657    4.5
#
#    review_count                       categories                 user_id  \
# 0           110  Restaurants, Breakfast & Brunch  8H-17uPX904DiVyNFIixPg
# 1           110  Restaurants, Breakfast & Brunch  ukgieEhXwin4YRqsdguLrA
# 2           110  Restaurants, Breakfast & Brunch  H6frBOvhhQbs7HWKcH1lNA
# 3           110  Restaurants, Breakfast & Brunch  tQCc9h1zjbMbrPYGfrMKJg
# 4           110  Restaurants, Breakfast & Brunch  94cMFXuUjTdaKWnxRJjTkg
#
#    review_stars        date
# 0             5  2019-02-10
# 1             2  2013-12-27
# 2             5  2018-10-07
# 3             5  2017-10-30
# 4             5  2015-09-17

# %%
# Create engine using the `spacex.sqlite` database file
engine = create_engine("sqlite:///santa_barbara_clean.sqlite")

# %%
# write to the database
Santa_Barbara_Clean.to_sql("santa_barbara", con=engine, index=False, if_exists="replace", chunksize=500)
# Out:
# 105000

# %%
# INSPECT to confirm existence

# Create the inspector and connect it to the engine
inspector_gadget = inspect(engine)

# Collect the names of tables within the database
tables = inspector_gadget.get_table_names()

# print metadata for each table
for table in tables:
    print(table)
    print("-----------")
    
    # get columns
    columns = inspector_gadget.get_columns(table)
    for column in columns:
        print(column["name"], column["type"])

    print()
# Out:
# santa_barbara
# -----------
# business_id TEXT
# name TEXT
# address TEXT
# city TEXT
# state TEXT
# postal_code BIGINT
# latitude FLOAT
# longitude FLOAT
# stars FLOAT
# review_count BIGINT
# categories TEXT
# user_id TEXT
# review_stars BIGINT
# date TEXT

# %%
# Define User Inputs (x=date range, y=avg.stars of user reviews )

# Pick a restaurant name
restaurant = "Jeni's Splendid Ice Creams"
restaurant_filter = Santa_Barbara_Clean[Santa_Barbara_Clean['name'] == restaurant]

# Select a date range
start_date = '2020-01-01'
end_date = '2021-01-01'
date_range = Santa_Barbara_Clean[(Santa_Barbara_Clean['date'] >= start_date) & (Santa_Barbara_Clean['date'] <= end_date)]

# %%
# build the query
query = f"""
    SELECT
        name,
        review_stars,
        date
    FROM
        santa_barbara
    WHERE
        name = :restaurant
        AND date BETWEEN :start_date AND :end_date
    ORDER BY
        name
"""

# execute query
params = {'restaurant': restaurant, 'start_date': start_date, 'end_date': end_date}
df = pd.read_sql(text(query), con=engine, params=params)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# OperationalError: near "AND": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[40], line 17
#      15 # execute query
#      16 params = {'restaurant': restaurant, 'start_date': start_date, 'end_date': end_date}
# ---> 17 df = pd.read_sql(text(query), con=engine, params=params)
#      18 df.head(10)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\io\sql.py:734, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     724     return pandas_sql.read_table(
#     725         sql,
#     726         index_col=index_col,
#    (...)
#     731         dtype_backend=dtype_backend,
#     732     )
#     733 else:
# --> 734     return pandas_sql.read_query(
#     735         sql,
#     736         index_col=index_col,
#     737         params=params,
#     738         coerce_float=coerce_float,
#     739         parse_dates=parse_dates,
#     740         chunksize=chunksize,
#     741         dtype_backend=dtype_backend,
#     742         dtype=dtype,
#     743     )
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\io\sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1779 def read_query(
#    1780     self,
#    1781     sql: str,
#    (...)
#    1788     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1789 ) -> DataFrame | Iterator[DataFrame]:
#    1790     """
#    1791     Read SQL query into a DataFrame.
#    1792
#    (...)
#    1834
#    1835     """
# -> 1836     result = self.execute(sql, params)
#    1837     columns = result.keys()
#    1839     if chunksize is not None:
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\io\sql.py:1660, in SQLDatabase.execute(self, sql, params)
#    1658 if isinstance(sql, str):
#    1659     return self.con.exec_driver_sql(sql, *args)
# -> 1660 return self.con.execute(sql, *args)
#
# File ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\sql\elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     515     if TYPE_CHECKING:
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#     521     raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342 elif should_wrap:
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#    2346     assert exc_info[1] is not None
#
# File ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)
#    1980         context.executemany,
#    1981     )
#
# File ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) near "AND": syntax error
# [SQL:
#     SELECT
#         name,
#         review_stars,
#         date
#     FROM
#         santa_barbara
#     WHERE
#         AND date BETWEEN ? AND ?
#     ORDER BY
#         name
# ]
# [parameters: ('2020-01-01', '2021-01-01')]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
filter1 = Santa_Barbara_Clean[Santa_Barbara_Clean['name'] == restaurant]
chart = filter1[(filter1['date'] >= start_date) & (filter1['date'] <= end_date)]

chart.head()
# Out:
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, review_count, categories, user_id, review_stars, date]
# Index: []

# %%
dev_avg_rating = over_200_reviews.groupby('Developers')['Rating'].mean()
dev_avg_playing = over_200_reviews.groupby('Developers')['Playing'].mean()

# %%
# Think we break the column into a list, value count the individual names, and then drop what we need. That is just first thought. May be an easier way.

# %%
# Not a list yet
# Santa_Barbara_Clean['categories'].unique()
# Out:
# array(['Restaurants, Breakfast & Brunch',
#        'American (Traditional), Restaurants, Shopping Centers, Shopping, Local Flavor',
#        'Restaurants, Mexican',
#        'Bars, Restaurants, Nightlife, Sandwiches, American (New), Tapas Bars, Wine Bars',
#        'Restaurants, American (Traditional), Lounges, Nightlife, Bars, Burgers, American (New)',
#        'Salad, Sandwiches, Restaurants, Pizza', 'Restaurants, Chinese',
#        'Restaurants, American (Traditional), American (New), Salad, Pizza, Gluten-Free',
#        'Sandwiches, Restaurants, American (New)',
#        'Bubble Tea, Restaurants, Food, Asian Fusion, Vegan, Acai Bowls',
#        'Coffee & Tea, Fast Food, Food, Restaurants, Burgers',
#        'American (Traditional), Restaurants, Wine Bars, Pizza, Cocktail Bars, Bars, Vegan, Nightlife',
#        'Restaurants, Japanese, Sushi Bars',
#        'Restaurants, Mexican, Fast Food',
#        'Restaurants, Event Planning & Services, Hotels, Hotels & Travel',
#        'Pizza, Restaurants, Sandwiches, Salad',
#        'Coffee Roasteries, Acai Bowls, Food, Coffee & Tea, Sandwiches, Bagels, Restaurants, Cafes',
#        'Farmers Market, American (Traditional), American (New), Food, Restaurants',
#        'Bakeries, Restaurants, Delis, Grocery, Specialty Food, Health Markets, Beer, Wine & Spirits, Food, American (New)',
#        'Nightlife, Arts & Entertainment, Restaurants, Dance Clubs, Bars, Music Venues, Mexican, Sports Bars',
#        'American (Traditional), Restaurants, Bars, Cocktail Bars, Nightlife, American (New), Sandwiches',
#        'Breakfast & Brunch, Restaurants, Bakeries, Food, Australian',
#        'Restaurants, Seafood, American (New), Steakhouses',
#        'Restaurants, Food, Desserts',
#        'Coffee & Tea, Restaurants, Specialty Food, Beer, Wine & Spirits, Food, Health Markets, Grocery, Fruits & Veggies',
#        'Restaurants, American (New), Barbeque, Food, Sandwiches, Wine Bars, Diners, Bars, Specialty Food, American (Traditional), Nightlife',
#        'Tapas/Small Plates, Restaurants, Breakfast & Brunch, Seafood, American (New)',
#        'Mexican, Tacos, Restaurants, Barbeque, Food Delivery Services, Food Trucks, Food, Event Planning & Services, Caterers',
#        'Salad, Sandwiches, Restaurants',
#        'Restaurants, Vegetarian, Salad, Coffee & Tea, Tex-Mex, American (Traditional), Burgers, Food, Sandwiches, Mexican, Juice Bars & Smoothies',
#        'Restaurants, Coffee & Tea, Breakfast & Brunch, Food, Cafes',
#        'Pop-Up Restaurants, Restaurants, Food, Donuts',
#        'Lounges, American (New), Burgers, Cocktail Bars, Bars, Sports Bars, Nightlife, Restaurants',
#        'Pizza, Gluten-Free, Restaurants, Event Planning & Services, Caterers',
#        'Comfort Food, Bakeries, Food, Desserts, Restaurants, Empanadas, Argentine',
#        'Japanese, Restaurants, Beer, Wine & Spirits, Food, Sushi Bars',
#        'Coffee & Tea, Restaurants, Food',
#        'Juice Bars & Smoothies, Restaurants, Food',
#        'Restaurants, Pizza, Chicken Wings, Sandwiches',
#        'Food, Restaurants, Middle Eastern, Cafes, Bakeries',
#        'Food, Coffee & Tea, Restaurants',
#        'Cafes, Burgers, Sandwiches, Restaurants',
#        'Wine Tasting Room, Tasting Classes, Bars, Wineries, Wine Bars, Tours, Food, Education, Wine Tasting Classes, Restaurants, Hotels & Travel, Nightlife, Barbeque, Wine Tours, Arts & Entertainment',
#        'Pizza, Restaurants, Chicken Wings, Salad, Sandwiches',
#        'Food, Cafes, Bakeries, Restaurants',
#        'Juice Bars & Smoothies, Breakfast & Brunch, Brazilian, Restaurants, Food, Salad, Acai Bowls',
#        'Active Life, Restaurants, Boating',
#        'Breakfast & Brunch, Diners, Nightlife, Restaurants, Comfort Food, American (New), Burgers, Salad',
#        'Food, Mexican, Restaurants, Seafood, Desserts',
#        'Restaurants, Fish & Chips, Food, Seafood, American (Traditional), Fast Food, Coffee & Tea, Breakfast & Brunch',
#        'Restaurants, Italian',
#        'Coffee & Tea, Food, Ice Cream & Frozen Yogurt, Restaurants, Cafes',
#        'Mexican, Restaurants', 'Restaurants, Pizza, Salad, Chicken Wings',
#        'Restaurants, American (New), Italian, Breakfast & Brunch, Seafood',
#        'Coffee & Tea, Breakfast & Brunch, Restaurants, French, Salad, Sandwiches, Desserts, Bakeries, Food',
#        'Chinese, Restaurants', 'Restaurants, Sandwiches, American (New)',
#        'Tacos, Restaurants, Mexican', 'Delis, Food, Restaurants, Grocery',
#        'Wine Tasting Room, Jazz & Blues, Tapas Bars, Wineries, Food, Wine Bars, Champagne Bars, Music Venues, Arts & Entertainment, Restaurants, Bakeries, Bars, Nightlife',
#        'Food Trucks, Tacos, Mexican, Salad, Food, Restaurants',
#        'Restaurants, Bakeries, Breakfast & Brunch, Food, Coffee Roasteries, Coffee & Tea',
#        'Restaurants, Sushi Bars',
#        'Restaurants, Salad, Sandwiches, Italian, Pizza',
#        'Food, Mexican, Restaurants, Bakeries',
#        'Delis, Restaurants, Fast Food, Sandwiches',
#        'Gluten-Free, American (New), Restaurants, Sandwiches, Salad, Steakhouses, Delis, American (Traditional)',
#        'Seafood, American (New), Salad, Restaurants, Sandwiches',
#        'Mediterranean, Restaurants, Salad, Greek',
#        'Delis, Salad, Restaurants, Sandwiches, Burgers, American (Traditional)',
#        'Ramen, Vegetarian, Sushi Bars, Japanese, Restaurants',
#        'Bars, Tapas Bars, Cocktail Bars, Restaurants, Nightlife, Speakeasies',
#        'Cafes, Burgers, American (Traditional), Tacos, Seafood, Restaurants, Mexican',
#        'Delis, Restaurants',
#        'Fast Food, Food, Acai Bowls, Juice Bars & Smoothies, Restaurants',
#        'Ethnic Food, Restaurants, Mexican, Specialty Food, Imported Food, Food',
#        'Restaurants, American (Traditional)',
#        'Public Services & Government, Landmarks & Historical Buildings, Local Flavor, Restaurants, Tours, Shopping, Shopping Centers, Seafood, Hotels & Travel, Boat Tours',
#        'Restaurants, Pizza',
#        'Salad, Steakhouses, Restaurants, Nightlife, Seafood',
#        'Restaurants, Vegan, Tapas/Small Plates, Vegetarian, Bars, Farmers Market, Beer, Wine & Spirits, Beer Bar, Food, Cafes, Nightlife, Wine Bars',
#        'Cocktail Bars, Fish & Chips, Nightlife, Seafood, Restaurants, Bars',
#        'Delis, Food, Beer, Wine & Spirits, Convenience Stores, Grocery, Restaurants',
#        'Pop-Up Restaurants, Korean, Restaurants, Asian Fusion',
#        'Latin American, Restaurants, Mexican, New Mexican Cuisine',
#        'Restaurants, Breakfast & Brunch, American (Traditional)',
#        'Steakhouses, Burgers, Bars, Seafood, Cocktail Bars, Restaurants, Nightlife',
#        'Sandwiches, Pizza, Restaurants, Italian',
#        'Pop-Up Restaurants, Coffee & Tea, Food, Restaurants',
#        'Food, Live/Raw Food, Restaurants, Ice Cream & Frozen Yogurt, Asian Fusion, Poke, Seafood, Food Delivery Services',
#        'Food, Donuts, Restaurants, Sandwiches, Coffee & Tea',
#        'Fish & Chips, Seafood, Restaurants',
#        'Salad, Sandwiches, Restaurants, Delis',
#        'Food, Breakfast & Brunch, Grocery, Sandwiches, Beer, Wine & Spirits, Meat Shops, Delis, Specialty Food, Restaurants, Health Markets',
#        'Seafood, Specialty Food, Seafood Markets, Farmers Market, Restaurants, Food',
#        'Restaurants, Sushi Bars, Japanese, Asian Fusion',
#        'Restaurants, Pizza, Italian', 'Sushi Bars, Restaurants',
#        'Diners, Restaurants',
#        'Restaurants, Bagels, Coffee & Tea, Food, Bubble Tea, Donuts',
#        'Cocktail Bars, Wine Bars, Nightlife, Bars, Beer Bar, Restaurants',
#        'Juice Bars & Smoothies, Food, Restaurants, Vegetarian',
#        'Lounges, Art Galleries, American (New), Bars, Shopping, Nightlife, Restaurants, Music Venues, Gastropubs, Cocktail Bars, Arts & Entertainment',
#        'Restaurants, Food, Fast Food, Burgers, Coffee & Tea',
#        'Seafood, Restaurants, American (Traditional)',
#        'Cafes, Restaurants, Cafeteria',
#        'Restaurants, Bars, Breakfast & Brunch, American (Traditional), Nightlife',
#        'Restaurants, Sandwiches, Salad, Fast Food',
#        'Fast Food, Chinese, Restaurants',
#        'Farmers Market, Food, Fast Food, American (New), Bars, Wine Bars, Breakfast & Brunch, Cafes, Restaurants, Nightlife',
#        'Fast Food, Restaurants, Coffee & Tea, Food, Burgers',
#        'Ramen, Japanese, Restaurants',
#        'Restaurants, Food Delivery Services, Nightlife, Cocktail Bars, Food, Tapas Bars, Bars',
#        'Wine Bars, Restaurants, Indian, Australian, Bars, American (New), Nightlife',
#        'Restaurants, American (New)',
#        'American (New), Food, Restaurants, American (Traditional)',
#        'Burgers, Restaurants',
#        'Gluten-Free, Gastropubs, Vegan, Restaurants, Indian',
#        'Tuscan, Seafood, Wine Bars, Restaurants, Bars, Nightlife, Italian',
#        'Restaurants, Breakfast & Brunch, American (Traditional), Burgers',
#        'Beer Bar, Sports Bars, Pubs, Bars, Restaurants, Cocktail Bars, Gastropubs, Nightlife, Tapas Bars',
#        'Thai, Restaurants',
#        'Restaurants, Fast Food, Tacos, Breakfast & Brunch, Burgers, Mexican',
#        'Art Galleries, Wine Bars, Shopping, Nightlife, Restaurants, Wineries, Bars, Food, Arts & Entertainment',
#        'Mexican, Restaurants, Breakfast & Brunch, Seafood',
#        'American (Traditional), American (New), Breakfast & Brunch, Restaurants, Seafood, Vegetarian, Nightlife, Event Planning & Services, Bars, Venues & Event Spaces',
#        'Restaurants, Chinese, Fast Food',
#        'Cafes, Restaurants, Sandwiches, Chicken Shop, Salad, American (New), Burgers, Breakfast & Brunch',
#        'Restaurants, Mexican, Salad',
#        'Seafood, American (New), Sandwiches, Steakhouses, Restaurants, Bars, Nightlife',
#        'Coffee & Tea, Food, Restaurants, Breakfast & Brunch, Bakeries, Sandwiches, Tabletop Games, Shopping',
#        'Mexican, Bars, Tex-Mex, Nightlife, Dance Clubs, Sports Bars, Restaurants',
#        'Wineries, Food, Breweries, Nightlife, Bars, Arts & Entertainment, Champagne Bars, Pubs, American (New), Brewpubs, Restaurants',
#        'Health & Medical, Restaurants, Mexican, Cannabis Clinics, Barbeque',
#        'Cajun/Creole, Breakfast & Brunch, Caterers, Restaurants, Event Planning & Services, Burgers',
#        'Italian, Salad, Pizza, Restaurants, Sandwiches',
#        'Restaurants, American (New), Breakfast & Brunch, Diners',
#        'Seafood, Nightlife, Hotels, Event Planning & Services, American (New), Bars, Diners, Restaurants, Hotels & Travel, Breakfast & Brunch',
#        'Food, Breakfast & Brunch, Bakeries, Restaurants, Coffee & Tea',
#        'Bars, Mediterranean, Burgers, Restaurants, Gastropubs, Nightlife, Whiskey Bars, Cocktail Bars',
#        'Health Markets, Food, Juice Bars & Smoothies, Specialty Food, Grocery, Restaurants, Delis, Meat Shops',
#        'Korean, Barbeque, Restaurants',
#        'Cafes, Restaurants, Breakfast & Brunch',
#        'Restaurants, Food, American (New), Wine Bars, Nightlife, Venues & Event Spaces, Bars, Event Planning & Services',
#        'Sushi Bars, Japanese, Restaurants', 'Italian, Restaurants',
#        'Restaurants, Beauty & Spas, American (New), Event Planning & Services, Hotels, Massage, Resorts, Day Spas, Hotels & Travel, Venues & Event Spaces',
#        'Pizza, Restaurants, Italian, Vegan, Gluten-Free, Sandwiches',
#        'Restaurants, Bars, Caterers, Mexican, Salad, Event Planning & Services, Desserts, Food, Nightlife',
#        'American (New), Tapas/Small Plates, Event Planning & Services, Venues & Event Spaces, Restaurants, Burgers',
#        'Restaurants, Barbeque, Food, Caterers, Event Planning & Services',
#        'American (Traditional), Event Planning & Services, Caterers, Restaurants, American (New), Cafes, Sandwiches, Breakfast & Brunch',
#        'Tapas/Small Plates, Desserts, Restaurants, Breakfast & Brunch, Food, Seafood',
#        'Delis, Sandwiches, Food, International Grocery, Restaurants, Ethnic Food, Grocery, Specialty Food',
#        'Desserts, Food, Bars, Wine Bars, Coffee & Tea, Nightlife, Tapas/Small Plates, Restaurants',
#        'American (New), Wraps, Chinese, Sushi Bars, Barbeque, Dim Sum, Asian Fusion, Ramen, Restaurants, Noodles, Soup, Japanese, Hot Pot',
#        'Salad, Sandwiches, Vegetarian, Restaurants, Chicken Wings',
#        'Restaurants, Nightlife, Mexican, Bars, Cocktail Bars',
#        'Breweries, American (New), Arts & Entertainment, Music Venues, Restaurants, Brewpubs, Food, Nightlife',
#        'Food, Bakeries, Restaurants, Patisserie/Cake Shop, Cafes, Coffee & Tea',
#        'Vietnamese, Pizza, Breakfast & Brunch, Restaurants, Gluten-Free',
#        'Italian, Restaurants, American (New), Mediterranean',
#        'Cocktail Bars, Bars, Restaurants, Breakfast & Brunch, Nightlife, Seafood, Cuban',
#        'Cafes, Restaurants, Bakeries, Coffee & Tea, Juice Bars & Smoothies, Food',
#        'Organic Stores, Breakfast & Brunch, Live/Raw Food, Juice Bars & Smoothies, Food, Restaurants',
#        'Restaurants, Fast Food, Mexican, Burgers, Tacos, Breakfast & Brunch',
#        'Szechuan, Chinese, Nightlife, Karaoke, Asian Fusion, Restaurants',
#        'Restaurants, Event Planning & Services, American (Traditional), Venues & Event Spaces',
#        'American (Traditional), Restaurants, Cafes, Coffee & Tea, Food',
#        'Restaurants, Breakfast & Brunch, Latin American, Mexican, Seafood',
#        'Chicken Wings, Restaurants',
#        'Restaurants, Delis, Food, Specialty Food, Grocery, Sandwiches',
#        'Sandwiches, Restaurants, Fast Food, Breakfast & Brunch',
#        'Sandwiches, Breakfast & Brunch, Restaurants, Fast Food',
#        'Bakeries, Mexican, Restaurants, Food',
#        'Ice Cream & Frozen Yogurt, Juice Bars & Smoothies, Convenience Stores, Vegan, Food, Health Markets, Specialty Food, Restaurants',
#        'Wine Tours, Food Tours, Tours, Restaurants, Food, Arts & Entertainment, Hotels & Travel, Walking Tours',
#        'Mediterranean, Bars, Restaurants, Nightlife',
#        'Music Venues, Bars, Nightlife, Arts & Entertainment, Restaurants, American (Traditional)',
#        'Food, Juice Bars & Smoothies, Restaurants, Coffee & Tea, Breakfast & Brunch, Sandwiches',
#        'Delis, Food, Restaurants, Bakeries',
#        'Food, Restaurants, Delis, Event Planning & Services, Caterers, Sandwiches',
#        'Korean, Restaurants, American (New), Mexican, Tacos, Nightlife, Fast Food, Bars',
#        'Food, Italian, Pizza, Fast Food, Gelato, Chicken Wings, Sandwiches, Salad, Restaurants',
#        'Restaurants, Salad, Soup, Sandwiches, Breakfast & Brunch',
#        'Restaurants, Vegan, Gluten-Free, Falafel, Mediterranean, Salad, Sandwiches',
#        'Lounges, Karaoke, American (New), Mexican, Sports Bars, Tacos, Restaurants, Pizza, Bars, Nightlife, Food, Beer, Wine & Spirits',
#        'Bars, Tacos, Mexican, Food, Beer, Wine & Spirits, Beer Bar, Nightlife, Restaurants',
#        'Desserts, Restaurants, Food, Breakfast & Brunch, Delis, Food Trucks',
#        'Diners, Salad, American (Traditional), Breakfast & Brunch, Restaurants',
#        'Caterers, Italian, Food Delivery Services, American (New), Event Planning & Services, Restaurants, Food',
#        'Delis, Restaurants, Coffee & Tea, Food, Salad',
#        'Hotels & Travel, Event Planning & Services, American (New), Italian, Hotels, Restaurants, Pizza, Breakfast & Brunch, Bars, Nightlife',
#        'Food, Restaurants, Donuts',
#        'Nightlife, Breweries, Restaurants, Food, Pizza, Beer Bar, Bars',
#        'Food, Beer, Wine & Spirits, Specialty Food, Delis, Grocery, Restaurants',
#        'Breakfast & Brunch, Food, Beer, Wine & Spirits, Bars, Seafood, Restaurants, Wine Bars, Cocktail Bars, American (New), Nightlife',
#        'Restaurants, Sandwiches, Chicken Shop, Chicken Wings, Fast Food, Caterers, Event Planning & Services',
#        'American (New), Mexican, Restaurants',
#        'Restaurants, Grocery, Food, Delis, Beer, Wine & Spirits',
#        'Steakhouses, Bars, Brewpubs, Breweries, American (Traditional), Nightlife, Sports Bars, Restaurants, Food, Burgers, Comfort Food, Seafood',
#        'Cafes, Restaurants, American (Traditional), Cocktail Bars, Breakfast & Brunch, Food, Beer, Wine & Spirits, American (New), Bars, Nightlife',
#        'Gelato, Food, Restaurants, Italian, Vegetarian, Gluten-Free',
#        'Seafood, Food, Specialty Food, Meat Shops, Restaurants, Seafood Markets',
#        'Delis, Nightlife, Bars, Food, Wine Bars, Restaurants, Coffee & Tea, Sandwiches, Wineries, Specialty Food, Arts & Entertainment, Cheese Shops',
#        'Restaurants, Burgers',
#        'Restaurants, American (Traditional), Seafood, Breakfast & Brunch',
#        'Burgers, Fast Food, Restaurants',
#        'Restaurants, American (New), Delis, Breakfast & Brunch, Tapas/Small Plates, Cafes',
#        'Restaurants, American (New), Seafood, Steakhouses',
#        'Bakeries, Food, Patisserie/Cake Shop, Cafes, Restaurants',
#        'Restaurants, Tacos, Mexican, Event Planning & Services, Food, Food Trucks, Caterers',
#        'Fast Food, Restaurants, Pizza, Salad',
#        'American (New), Beer, Wine & Spirits, Food, Japanese, Bars, Asian Fusion, Ramen, Restaurants, Cocktail Bars, Nightlife',
#        'Breakfast & Brunch, American (New), Restaurants, American (Traditional), Nightlife, Bars',
#        'Restaurants, Bars, Irish, Nightlife, Pubs, Gastropubs',
#        'Coffee & Tea, Restaurants, Cafes, Food, Acai Bowls, Juice Bars & Smoothies',
#        'Thai, Vegetarian, Noodles, Restaurants, Asian Fusion',
#        'Pakistani, Restaurants, Buffets, Seafood, Halal, Indian, Vegetarian, Vegan, Food, Salad, Desserts',
#        'Beer Bar, Breakfast & Brunch, Vegan, Bars, Nightlife, Restaurants',
#        'Restaurants, Breakfast & Brunch, Sandwiches, Coffee & Tea, Food',
#        'Food, Restaurants, Bakeries, Desserts',
#        'American (Traditional), American (New), French, Restaurants',
#        'American (Traditional), Bakeries, Restaurants, Italian, Breakfast & Brunch, Food',
#        'Soul Food, Wine Tasting Room, Food, Restaurants, Arts & Entertainment, Vegan, Mexican, American (Traditional), Nightlife, Wineries, Bars',
#        'Vietnamese, Restaurants, Bars, Seafood, Wine Bars, Vegetarian, Nightlife, Noodles',
#        'Restaurants, Indian, Himalayan/Nepalese',
#        'American (Traditional), Restaurants',
#        'Restaurants, Nightlife, Bars, Food, American (New), Piano Bars, Beer, Wine & Spirits, Cocktail Bars',
#        'Mexican, Breakfast & Brunch, Restaurants, Seafood',
#        'Pizza, Restaurants, Italian, Vegetarian',
#        'Seafood, Cajun/Creole, American (New), Restaurants',
#        'Restaurants, Food, Juice Bars & Smoothies, Breakfast & Brunch',
#        'Sandwiches, Chinese, Cocktail Bars, Restaurants, Nightlife, Salad, Delis, Bars, Lounges',
#        'Tapas Bars, Restaurants',
#        'Sandwiches, Pop-Up Restaurants, American (Traditional), Restaurants, Burgers',
#        'American (Traditional), Seafood, Sandwiches, Restaurants, Burgers, Breakfast & Brunch',
#        'Restaurants, Event Planning & Services, Caterers, Pizza, Food Trucks, Food',
#        'Chicken Shop, Desserts, Food, Breakfast & Brunch, Barbeque, Mexican, Bars, Nightlife, Cocktail Bars, Restaurants',
#        'Restaurants, Food, Coffee & Tea',
#        'American (New), Restaurants, Salad, Burgers',
#        'Food Trucks, Event Planning & Services, Mexican, Street Vendors, Caterers, Restaurants, Food',
#        'Szechuan, Chinese, Restaurants',
#        'Restaurants, Sushi Bars, Food, Specialty Food, Japanese',
#        'American (New), Italian, Bars, Restaurants, Nightlife, Food, Beer, Wine & Spirits',
#        'Restaurants, Juice Bars & Smoothies, Food',
#        'Restaurants, Tapas/Small Plates',
#        'Nightlife, Bars, Gastropubs, Restaurants, American (New)',
#        'Food, Specialty Food, Seafood, Cajun/Creole, Restaurants',
#        'Mediterranean, Restaurants, French, Breakfast & Brunch, American (New), Seafood, Buffets, Italian',
#        'Hotels, Restaurants, Beauty & Spas, Hotels & Travel, Day Spas, Event Planning & Services',
#        'Restaurants, Sushi Bars, Japanese',
#        'Restaurants, Vegetarian, Tex-Mex, Sandwiches',
#        'American (New), Food, Restaurants, Coffee & Tea, Breakfast & Brunch',
#        'Restaurants, Burgers, Food, Fast Food, Coffee & Tea',
#        'Bars, American (Traditional), Gastropubs, Nightlife, Cocktail Bars, Restaurants, American (New)',
#        'Restaurants, Nightlife, Burgers, American (Traditional), American (New), Fast Food, Sandwiches, Food Delivery Services, Food',
#        'Nightlife, Seafood, American (Traditional), Bars, Restaurants',
#        'Seafood, Bars, Wine Bars, American (New), Restaurants, French, Nightlife, Mexican',
#        'Pop-up Shops, Wine Tasting Room, Shopping Centers, Restaurants, Shopping, Food, Beer, Wine & Spirits, Arts & Entertainment, Wineries, American (Traditional)',
#        'Pizza, Sandwiches, Chicken Wings, Restaurants',
#        'Restaurants, American (New), French',
#        'Restaurants, Sandwiches, Chicken Wings, Salad, Italian, Pizza',
#        'Restaurants, Mexican, Breakfast & Brunch',
#        'Food, American (New), Thai, Restaurants, Asian Fusion, Desserts, Cafes, Sandwiches, Caterers, Event Planning & Services',
#        'Food, Grocery, Korean, Restaurants, International Grocery',
#        'Specialty Food, Health Markets, Restaurants, Gluten-Free, Bakeries, Coffee & Tea, Desserts, Breakfast & Brunch, Food',
#        'Comfort Food, Asian Fusion, Chinese, Tapas/Small Plates, Noodles, Thai, Restaurants',
#        'Restaurants, Food, Live/Raw Food, Juice Bars & Smoothies, Vegan',
#        'Restaurants, Thai, Food, Chicken Wings, Ice Cream & Frozen Yogurt, Desserts',
#        'Restaurants, Coffee & Tea, American (Traditional), Breakfast & Brunch, Food, Diners',
#        'Restaurants, Vietnamese, Vegetarian',
#        'Soup, Thai, Restaurants, Noodles',
#        'Coffee & Tea, Cafes, Restaurants, Food', 'Fast Food, Restaurants',
#        'Cafeteria, Cafes, American (New), Restaurants, Sandwiches, Pizza, Mexican',
#        'American (Traditional), Restaurants, Burgers',
#        'Bars, Cocktail Bars, American (Traditional), Restaurants, Nightlife',
#        'Mexican, Fast Food, Tex-Mex, Restaurants',
#        'Salad, Restaurants, Event Planning & Services, Food Delivery Services, Personal Chefs, Caterers, Food',
#        'Vegan, American (New), Restaurants',
#        'Ethiopian, Soul Food, Restaurants, Comfort Food',
#        'Restaurants, Pop-Up Restaurants',
#        'Nightlife, Gay Bars, Wine Bars, Bars, Cupcakes, Desserts, Tapas Bars, Beer Bar, Food, Restaurants',
#        'Restaurants, New Mexican Cuisine, Mexican, Fast Food',
#        'Restaurants, Bars, Nightlife, American (New), American (Traditional)',
#        'Italian, Cafes, Mediterranean, Restaurants',
#        'Restaurants, Italian, Pizza',
#        'Restaurants, Sandwiches, Breakfast & Brunch, Coffee & Tea, Food, Juice Bars & Smoothies',
#        'Restaurants, Wine Bars, Seafood, Bars, Nightlife, Chinese, Vegetarian, Dim Sum',
#        'Nightlife, Restaurants, Steakhouses, Bars',
#        'Coffee & Tea, Food, Desserts, Turkish, Restaurants, Bakeries',
#        'Restaurants, Middle Eastern, Bars, Nightlife, Mediterranean, Lebanese',
#        'Food, Restaurants, Cafes, Coffee & Tea, Beer, Wine & Spirits, Pizza',
#        'Burgers, Restaurants, Mexican',
#        'Restaurants, Food, French, Coffee & Tea, Bakeries, Breakfast & Brunch',
#        'American (New), Breakfast & Brunch, Restaurants, Salad, Italian, Nightlife, Bars, Beer, Wine & Spirits, Sandwiches, Coffee & Tea, Wine Bars, Food, Pizza',
#        'Restaurants, Ethiopian, French',
#        'Food, Restaurants, Coffee & Tea',
#        'French, Cafes, Restaurants, Breakfast & Brunch, Food, Sandwiches, Bakeries',
#        'Hot Dogs, Restaurants',
#        'Bars, Nightlife, Tapas/Small Plates, Tapas Bars, Restaurants, Lounges',
#        'Restaurants, Food, Breakfast & Brunch, Bakeries',
#        'Pizza, Italian, Fast Food, Restaurants',
#        'Restaurants, Breakfast & Brunch, Sandwiches, American (Traditional)',
#        'Nightlife, Bars, Cocktail Bars, Food, American (New), Desserts, Restaurants',
#        'Bars, Tapas/Small Plates, Japanese, Nightlife, Restaurants, Sushi Bars, Cocktail Bars, Asian Fusion',
#        'Juice Bars & Smoothies, Restaurants, Food, Vegan, Cafes, Bakeries, Coffee & Tea, Gluten-Free, Vegetarian, Acai Bowls',
#        'Venues & Event Spaces, Cafes, Wine Bars, Event Planning & Services, Nightlife, Bars, Restaurants, American (New)',
#        'Food, Breweries, Beer Gardens, Mediterranean, Nightlife, Restaurants',
#        'Vegan, Vegetarian, Sandwiches, Restaurants',
#        'Cocktail Bars, Farmers Market, Tapas Bars, Food, Desserts, Nightlife, Asian Fusion, Restaurants, Tapas/Small Plates, Bars, Indonesian',
#        'Breakfast & Brunch, Bocce Ball, Event Planning & Services, Beer, Wine & Spirits, Venues & Event Spaces, Italian, Active Life, Food, Wedding Planning, Restaurants',
#        'Trivia Hosts, Nightlife, Sports Bars, Beer Gardens, Event Planning & Services, Restaurants, Bars, Beer Bar',
#        'Restaurants, Sandwiches, Specialty Food, Pasta Shops, Grocery, Food, Ethnic Grocery, Delis',
#        'Steakhouses, Cafes, American (Traditional), Seafood, Breakfast & Brunch, Restaurants, Sandwiches',
#        'Bakeries, Cafes, Coffee & Tea, Food, Desserts, Breakfast & Brunch, Restaurants',
#        'Donuts, Restaurants, Food',
#        'Event Planning & Services, Caterers, Sandwiches, Bars, Steakhouses, Delis, Nightlife, Burgers, Cafes, American (New), Restaurants, American (Traditional)',
#        'Specialty Food, Beer, Wine & Spirits, Grocery, Bakeries, Restaurants, Delis, Butcher, Food',
#        'Nightlife, American (Traditional), Cafes, Restaurants, Wine Bars, Breakfast & Brunch, Bars',
#        'Restaurants, Hot Dogs',
#        'Nightlife, Wine Bars, Bars, American (Traditional), Tapas/Small Plates, Tapas Bars, Food, Arts & Entertainment, Wine Tasting Room, Wineries, American (New), Restaurants',
#        'Patisserie/Cake Shop, French, Food, Restaurants, Bakeries, Cupcakes',
#        'Restaurants, Specialty Food, Do-It-Yourself Food, Seafood Markets, Food, Caterers, Seafood, Breakfast & Brunch, Event Planning & Services',
#        'Chinese, Food, Dim Sum, Desserts, Coffee & Tea, Restaurants',
#        'Fast Food, Breakfast & Brunch, Restaurants, Mexican, Tex-Mex, Tacos',
#        'Food, Beer, Wine & Spirits, Hot Dogs, Restaurants',
#        'Salad, Restaurants, Pizza, Sandwiches, Italian',
#        'Modern European, Nightlife, Bars, Restaurants, Bakeries, Wine Bars, Food, Scandinavian, Breakfast & Brunch',
#        'Pizza, Restaurants',
#        'Restaurants, Convenience Stores, Food, Grocery',
#        'Nightlife, Beer Gardens, Restaurants, Pizza, Hot Dogs',
#        'Restaurants, Latin American, Mexican, Tacos',
#        'Restaurants, Vegan',
#        'Restaurants, Gastropubs, Cocktail Bars, Bars, American (New), Nightlife, Beer Bar, American (Traditional)',
#        'Chicken Wings, Restaurants, Fast Food, Chicken Shop',
#        'Coffee & Tea, Food, Bagels, Breakfast & Brunch, Restaurants',
#        'Seafood, American (Traditional), Breakfast & Brunch, Restaurants',
#        'Pizza, Nightlife, Italian, Restaurants, Bars',
#        'Health Retreats, Venues & Event Spaces, Hotels & Travel, Restaurants, Event Planning & Services',
#        'Food Trucks, Caterers, Seafood, Restaurants, Event Planning & Services, Food',
#        'Hotels & Travel, Hotels, Event Planning & Services, Restaurants, Venues & Event Spaces, Resorts',
#        'Thai, Restaurants, Food, Donuts',
#        'Bakeries, Sandwiches, Food, Restaurants, American (Traditional)',
#        'Seafood, Restaurants, Hawaiian, American (New), Breakfast & Brunch',
#        'Sandwiches, Restaurants, Delis, Breakfast & Brunch',
#        'Restaurants, Cocktail Bars, Salad, Bars, Burgers, American (New), Nightlife, Barbeque',
#        'Restaurants, Nightlife, American (New), Food, Farmers Market, Bars, Wine Bars',
#        'Restaurants, Delis, Coffee & Tea, Breakfast & Brunch, Food, Gluten-Free, Cafes, Beer, Wine & Spirits',
#        'Seafood, Restaurants, Breakfast & Brunch, Lounges, Cocktail Bars, Mediterranean, Bars, Tapas/Small Plates, American (New), Nightlife',
#        'Caterers, Italian, Restaurants, Delis, Event Planning & Services',
#        'Restaurants, Chinese, Vegetarian',
#        'Breakfast & Brunch, Coffee & Tea, Bakeries, Desserts, Donuts, Food, Restaurants',
#        'Japanese, Restaurants, Sushi Bars, Vegetarian',
#        'Food, Local Flavor, Seafood, Arts & Entertainment, Shopping, Festivals, Restaurants, Arts & Crafts',
#        'Specialty Food, Grocery, Farmers Market, Shopping, Restaurants, Public Markets, Local Flavor, Food',
#        'Event Planning & Services, Nightlife, Tapas Bars, Spanish, Modern European, Bars, Cocktail Bars, Seafood, Venues & Event Spaces, Restaurants',
#        'Garage Door Services, Restaurants, Live/Raw Food, Food, Home Services, Mediterranean, Keys & Locksmiths, Burgers, Vegetarian, Juice Bars & Smoothies, Vegan, Salad',
#        'Restaurants, Coffee & Tea, Food',
#        'American (New), Pizza, Pubs, Nightlife, Bars, Restaurants, American (Traditional), Breakfast & Brunch, Beer Bar',
#        'Restaurants, Fast Food, Chinese',
#        'Breakfast & Brunch, Fast Food, Tex-Mex, Restaurants, Mexican, Tacos',
#        'American (New), American (Traditional), Bars, Restaurants, Salad, Burgers, Ice Cream & Frozen Yogurt, Food, Nightlife, Beer, Wine & Spirits, Beer Bar, Chicken Shop',
#        'Bars, Mediterranean, Restaurants, Nightlife, Moroccan, Event Planning & Services, Venues & Event Spaces, Italian',
#        'Delis, Gluten-Free, Fast Food, Salad, Sandwiches, Restaurants',
#        'Event Planning & Services, Latin American, Caterers, Food, Restaurants, Empanadas, Argentine',
#        'Restaurants, Sandwiches, Nightlife, Bars, American (New), Cocktail Bars',
#        'Salad, Restaurants, Vegetarian, Chicken Shop, Chicken Wings, Sandwiches, Nightlife',
#        'Restaurants, Pizza, Sandwiches, Chicken Wings',
#        'Restaurants, Coffee & Tea, Breakfast & Brunch, Gluten-Free, Food, Sandwiches, Bagels',
#        'Restaurants, Nightlife, Hotels & Travel, Hotels, Italian, Event Planning & Services',
#        'Mexican, Restaurants, Fish & Chips',
#        'Japanese, Restaurants, Noodles, Sushi Bars',
#        'Bakeries, Vegan, Specialty Food, Food Delivery Services, Food, Coffee & Tea, Gluten-Free, Farmers Market, Restaurants, Organic Stores'],
#       dtype=object)

# %%
# categories_to_drop = 'Restaurants|Food|Caterers|Event Planning & Services|Nightlife'

# %%
# mask = Santa_Barbara_Clean['categories'].str.replace(r'\b(?:' + categories_to_drop + r')\b', '', regex=True).str.strip()

# %%
# Santa_Barbara_Clean['categories'].value_counts()

# %%
# Save to new CSV
# Santa_Barbara_Clean.to_csv("Resources/Santa_Barbara_Clean.csv.csv", index=False)

# %%
# close the engine
engine.dispose()
